# %%
#liste and there operations
l=[1,2,3]
print(l)
# Out:
# [1, 2, 3]

# %%
l=[1,2,3,4,5]
print(len(l))
# Out:
# 5

# %%
l=[1,2,3,4,5,6]
l.remove(5)
print(l)
# Out:
# [1, 2, 3, 4, 6]

# %%
l=[1,2,3,4]
l.append(5)
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l=[1,2,3,4,5,6]
print(l[0])
print(l[5])
print(l[:5])
print(l[1:6])
print(l[1:])
# Out:
# 1
# 6
# [1, 2, 3, 4, 5]
# [2, 3, 4, 5, 6]
# [2, 3, 4, 5, 6]

# %%
l=[1,2,3,4,5]
print(l)
l1=[1,2,2,1,1,1]
print(l1)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 2, 1, 1, 1]

# %%
#tuple and operation
t=(1,2,3)
print(t)
# Out:
# (1, 2, 3)

# %%
t=(1,2,3,1)
print(t)
# Out:
# (1, 2, 3, 1)

# %%
t=(1,2,3,4)
t.append(5)
print(t)
#tuple is umutable mean we can't chage it by adding and removing items in the tuple
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_467/3500959097.py in <cell line: 0>()
#       1 t=(1,2,3,4)
# ----> 2 t.append(5)
#       3 print(t)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t=(1,3,4,2,1,4)
print(len(t))
# Out:
# 6

# %%
t=(1,2,3,4,5,6)
print(t[0])
print(t[3])
print(t[1:2])
print(t[0:])
print(t[:6])
# Out:
# 1
# 4
# (2,)
# (1, 2, 3, 4, 5, 6)
# (1, 2, 3, 4, 5, 6)

# %%
#set and there operation
s={1,2,3,4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s={1,2,34,5,2}
print(s)
#in sets it does't allow the dublecates
# Out:
# {1, 2, 34, 5}

# %%
s={1,22,3,4,4}
print(len(s))
# Out:
# 4

# %%
s1={1,2,3,4}
s2={2,3,4,5,6,78,9}
print("unien:",s1|s2)
print("interstion :",s1&s2)
print("differance:",s1-s2)
# Out:
# unien: {1, 2, 3, 4, 5, 6, 9, 78}
# interstion : {2, 3, 4}
# differance: {1}

# %%
s={1,2,3,4}
s.add(5)
print(s)
s.remove(5)
print(s)
# Out:
# {1, 2, 3, 4, 5}
# {1, 2, 3, 4}

# %%
#dicstnares and there opreationa
student={'name':'saniya','age':'20','dep':'cse'}
print(student)
# Out:
# {'name': 'saniya', 'age': '20', 'dep': 'cse'}

# %%
student['grade']='A'
print(student)
# Out:
# {'name': 'saniya', 'age': '20', 'dep': 'cse', 'grade': 'A'}

# %%
print(student['age'])
# Out:
# 20

# %%
del student['grade']
print(student)
# Out:
# {'name': 'saniya', 'age': '20', 'dep': 'cse'}
