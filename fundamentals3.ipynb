# %%
#variables
v=2
print(v)
# Out:
# 2

# %%
name="saniya"
age=20
print("NAME",name)
print("AGE",age)
# Out:
# NAME saniya
# AGE 20

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
a="saniya"
print(type(a))
# Out:
# <class 'str'>

# %%
b = 3.14
print(type(b))
# Out:
# <class 'float'>

# %%
#String
c = "Python"
print(type(c))

# Boolean
d = True
print(type(d))

# List
e = [1, 2, 3, "four"]
print(type(e), e)

# Dictionary
f = {"name": "Alice", "age": 25}
print(type(f), f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}

# %%
print("hello world ")
# Out:
# hello world

# %%
name=input("enter the name:")
print(name)
# Out:
# enter the name:saniya
# saniya

# %%
age = int(input("Enter your age: "))
print("You will be", age + 1, "next year.")
# Out:
# Enter your age: 20
# You will be 21 next year.
